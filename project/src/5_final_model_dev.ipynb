# %%
import pandas as pd
import numpy as np
import warnings
from datetime import datetime
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer, mean_squared_error


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.losses import Huber
import tensorflow as tf 
import matplotlib.pyplot as plt


warnings.filterwarnings("ignore")
# Out:
# 2023-10-01 23:39:31.991257: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Time Series Cross Validation Strategy
# 1. Because of the potential for underlying changes in the data generation process (in this case, changes in how teams strategize/play in the NBA), we should avoid using traditional k-fold cross validation and instead use a time series cross validation approach. This will also help us avoid any unintended data leakage.
#
# 2. Identify optimal hyper-parameters.
#
#     a. Use "blocked" rolling train/test splits (eg. train on 2015, test on random 25-50% of 2016, etc.) and average the MSE across the years to find the best parameters.
#
# 3. After identifying optimal hyper-parameters, train on a 4-year rolling window basis (ie. train on 2015-2018, test on 2019). Repeat this several times so that you get a better sense of what your profit/loss will look like by seeing how you would have done in 2019, 2020, 2021, 2022, etc.

# %% [markdown]
# #### Profit / Loss Simulation
# 1. Use rolling 4 year training period (eg. 2015-2018) and test P/L on following year (eg. 2019) at various point spread differentials (predicted spread vs. actual spread > X, for a series of X values)

# %% [markdown]
# # Model 1: Random Forest

# %% [markdown]
# The first thing we want to do is figure out which hyper-parameters work best for each model we are going to build. We figure this out by training on 1 year of data and then testing on a portion of the following year. By repeating this many times for different hyper-parameter combinations and taking the average MSE, we can figure out the best options. Then, we will use those config parameters when we train the actual models (using a rolling 4 years of data and testing on the entire subsequent year).

# %%
train_df = pd.read_csv('train_df.csv')

# Hyper-Parameter Tuning (RANDOM FOREST)
def custom_time_series_splits(df, season_col='SEASON'):
    for season in range(min(train_df.SEASON), max(train_df.SEASON)):  # For seasons 2015 to 2021 (2022 not included because we don't have 2023 season data to validate on yet)
        train_indices = df[df[season_col] == season].index.values
        test_indices = df[df[season_col] == season + 1].index.values
        # Randomly sample 50% of the test indices
        test_indices = np.random.choice(test_indices, size=int(1 * len(test_indices)), replace=False)
        yield train_indices, test_indices

# Create a Random Forest Regressor object
rf = RandomForestRegressor(random_state=42)

# Define the parameter grid
param_grid = {
    'n_estimators': [200, 400, 800],
    'max_features': ['sqrt', 'log2'],
    'max_depth': [None, 5, 10],
    # 'min_samples_split': ['auto',5,10,20],
    # 'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Define a scorer (using MSE)
scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Features/Predictors
X = train_df.drop(['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'], axis=1)
# Target
y = train_df['HOME PLUS MINUS']

# Use the generator for custom CV splits
cv_splits = list(custom_time_series_splits(train_df))

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=cv_splits, scoring=scorer, n_jobs=-1)
grid_search.fit(X, y)

# Obtain the cross-validation results
cv_results = grid_search.cv_results_

# Print the average validation score (MSE) for each parameter combination
for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
    print(f"Average Loss (MSE): {-mean_score:.4f} | Parameters: {params}")

best_params = grid_search.best_params_
print(f"\nBest parameters: {best_params}")
best_index = grid_search.best_index_

# Extract individual test scores for the best parameters
test_scores = []
for i in range(len(cv_splits)):  
    split_score_key = f"split{i}_test_score"
    test_scores.append(np.abs(grid_search.cv_results_[split_score_key][best_index]))

print(f"Individual test scores for the best parameters: {test_scores}")
print(f"Average MSE: {np.abs(np.mean(test_scores))}")
# Out:
# Average Loss (MSE): 186.6484 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 185.6764 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 185.4488 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 186.3076 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 185.4606 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 185.0521 | Parameters: {'bootstrap': True, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 800}
# Average Loss (MSE): 185.0478 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 184.6598 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 184.3961 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 184.7162 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 184.3128 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 184.1164 | Parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 800}
# Average Loss (MSE): 186.0864 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 185.3794 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 184.9217 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 185.1501 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 184.4822 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 184.4938 | Parameters: {'bootstrap': True, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 800}
# Average Loss (MSE): 189.8472 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 189.1750 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 189.1671 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 187.9572 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 187.7122 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 187.5697 | Parameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'log2', 'n_estimators': 800}
# Average Loss (MSE): 185.4652 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 185.2470 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 185.2461 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 185.5018 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 185.3567 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 185.2122 | Parameters: {'bootstrap': False, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 800}
# Average Loss (MSE): 188.7511 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 200}
# Average Loss (MSE): 187.8033 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 400}
# Average Loss (MSE): 187.6695 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'sqrt', 'n_estimators': 800}
# Average Loss (MSE): 187.4813 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 200}
# Average Loss (MSE): 186.8434 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 400}
# Average Loss (MSE): 186.5794 | Parameters: {'bootstrap': False, 'max_depth': 10, 'max_features': 'log2', 'n_estimators': 800}
#
# Best parameters: {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'n_estimators': 800}
# Individual test scores for the best parameters: [173.36144908824224, 167.04697011517288, 179.0006380551588, 173.97421531376298, 205.52925594531305, 217.59337040293627, 172.3091544311133]
# Average MSE: 184.11643619309993

# %%
# Now that we have identified the optimal hyper-parameters, let's build a series of 4-year training/1 year validation models to track MSE (and $ won or lost) over multiple years

def train_and_validate_models(df, best_params, season_col='SEASON'):
    trained_models = []
    validation_scores = []

    # Define the range of starting seasons for training data (2015 to 2018 inclusive) 
    # So, Model 1 will train using 2015 - 2018 and test on 2019. Model 2 will train on 2016 - 2019 and test on 2020, etc.
    for start_season in range(2015, 2019):
        # Split the data based on the seasons
        train_data = df[(df[season_col] >= start_season) & (df[season_col] <= start_season + 3)]
        test_data = df[df[season_col] == start_season + 4]

        # Extract features and target variable
        X_train = train_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_train = train_data['HOME PLUS MINUS']

        X_test = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_test = test_data['HOME PLUS MINUS']

        # Train the model using best hyperparameters identified previously
        model = RandomForestRegressor(**best_params)
        model.fit(X_train, y_train)

        # Validate the model on the test set
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)

        # Store the trained model and validation score
        trained_models.append(model)
        validation_scores.append(mse)

        print(f"Trained for seasons {start_season}-{start_season+3}, MSE on season {start_season+4}: {mse:.4f}")

    return trained_models, validation_scores

# Call the function
rf_models, rf_scores = train_and_validate_models(train_df, best_params)
# Out:
# Trained for seasons 2015-2018, MSE on season 2019: 173.6428
# Trained for seasons 2016-2019, MSE on season 2020: 201.0587
# Trained for seasons 2017-2020, MSE on season 2021: 214.2709
# Trained for seasons 2018-2021, MSE on season 2022: 169.4954

# %%
# Get feature importances for a given model (i = 0 is 2015-2018, i = 1 is 2016-2019 etc.)
i = 0
importances = rf_models[i].feature_importances_

# Sort and display the features by their importance
feature_importances = pd.DataFrame(rf_models[i].feature_importances_,
                                   index = X.columns,
                                    columns=['importance']).sort_values('importance', ascending=False)
feature_importances
# Out:
#                            importance
# HOME TEAM WIN PCT            0.145571
# AWAY TEAM WIN PCT            0.107585
# HOME TEAM PP100P             0.096231
# AWAY TEAM PP100P             0.067626
# AWAY TEAM 2PT PCT            0.057603
# HOME TEAM WIN PCT LAST 10    0.057143
# HOME TEAM OPP PP100P         0.053099
# HOME TEAM SOS                0.043690
# HOME TEAM 2PT PCT            0.043340
# AWAY TEAM DRB PCT            0.035919
# AWAY TEAM OPP PP100P         0.035801
# AWAY TEAM WIN PCT LAST 10    0.030322
# HOME TEAM DRB PCT            0.026304
# AWAY TEAM SOS                0.026156
# HOME TEAM 3PT PCT            0.024872
# HOME TEAM OPP 2PT PCT        0.022824
# AWAY TEAM OPP 2PT PCT        0.018851
# HOME TEAM ORB PCT            0.018412
# AWAY TEAM 3PT PCT            0.016382
# HOME TEAM OPP 3PT PCT        0.016069
# AWAY TEAM OPP 3PT PCT        0.013780
# HOME TEAM SOS LAST 10        0.011205
# AWAY TEAM SOS LAST 10        0.009911
# AWAY TEAM ORB PCT            0.009494
# HOME TEAM DAYS REST          0.005469
# AWAY TEAM DAYS REST          0.005138
# AWAY TEAM HOME PRIOR         0.000653
# HOME TEAM HOME PRIOR         0.000548

# %%
START_YEAR = min(train_df.SEASON) # For our data, the first year should be 2015
# Bet amount each game
BET_AMOUNT = 100
# Average betting site take rate
TAKE_RATE = 0.1

# Set your margin for level of confidence (higher value means the model needs to be more confident in order to place a bet)
for THRESHOLD in [6,8,10,12,14]:
    print('---------------------------------------')
    print('THRESHOLD:', THRESHOLD)


    # Loop through all models constructed and create a dataframe with the bet decision and the bet outcome
    for i, model in enumerate(rf_models):
        test_year = START_YEAR + 4 + i
        #print('Test Year:', test_year)
        test_data = train_df[train_df['SEASON'] == test_year].reset_index(drop=True)

        # Prepare data for inference
        X = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])

        # Create your vector of predictions
        y_pred = model.predict(X)

        decisions = []
        outcomes = []
        bets_made = 0 
        bets_won = 0
        bets_lost = 0
        bets_push = 0
        games = len(test_data)
        profit = 0
        net_bets_made = 0

        for index, row in test_data.iterrows():

            bet = None
            home_favored_bet_home = False 
            home_favored_bet_away = False
            away_favored_bet_home = False
            away_favored_bet_away = False
            no_favorite_bet_home = False
            no_favorite_bet_away = False 
            
            # Bet when home is favored AND you think home team will outperform the spread by THRESHOLD
            home_favored_bet_home = row['HOME SPREAD'] < 0 and (y_pred[index] - THRESHOLD > abs(row['HOME SPREAD']))

            # Bet when home is favored BUT you think the away team will outperform the spread by THRESHOLD
            home_favored_bet_away = row['HOME SPREAD'] < 0 and ((y_pred[index] < 0 and (abs(row['HOME SPREAD'] + y_pred[index]) > THRESHOLD)) or (y_pred[index] >= 0 and y_pred[index] + THRESHOLD < abs(row['HOME SPREAD'])))

            # Bet when away is favored BUT you think the home team will outperform the spread (you think home team wins outright, by at least a particular relative margin OR you think the away team wins, but not by as much as the market thinks)
            away_favored_bet_home = row['HOME SPREAD'] > 0 and (((y_pred[index] > 0 and y_pred[index] + row['HOME SPREAD'] > THRESHOLD)) or ((y_pred[index] <= 0) and abs(y_pred[index]) + THRESHOLD < row['HOME SPREAD']))

            # Bet when away is favored AND you think away team will outperform the spread by THRESHOLD
            away_favored_bet_away = row['HOME SPREAD'] > 0 and y_pred[index] < 0 and (abs(y_pred[index]) - THRESHOLD > row['HOME SPREAD'])

            # Bet when there is no favorite, but you think HOME will win by more than THRESHOLD
            no_favorite_bet_home = row['HOME SPREAD'] == 0 and (y_pred[index] > THRESHOLD)

            # Bet when there is no favorite, but you think AWAY will win by more than THRESHOLD
            no_favorite_bet_away = row['HOME SPREAD'] == 0 and (abs(y_pred[index]) > THRESHOLD)


            # Bet home or away
            if home_favored_bet_home or away_favored_bet_home or no_favorite_bet_home:
                bet = 'Bet on Home'
            elif home_favored_bet_away or away_favored_bet_away or no_favorite_bet_away:
                bet = 'Bet on Away'
            else: 
                bet = 'No Bet'

            # Outcomes
            if bet == 'Bet on Home':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']:  # HOME COVERED THE SPREAD
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
                else:
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                    
            elif bet == 'Bet on Away':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']: # HOME COVERED THE SPREAD
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                else: 
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
            else: 
                outcome = 'No Bet Placed'

            decisions.append(bet)
            outcomes.append(outcome)        
                        
            #print('Market home plus minus:', -row['HOME SPREAD'], '| Predicted home plus minus:', round(y_pred[index],1), '| Bet:', bet, ' | Actual home plus minus:', row['HOME PLUS MINUS'], '| Bet outcome:', outcome)

        if net_bets_made == 0:
            win_rate = 0
        else:
            win_rate = round(bets_won / net_bets_made, 2)

        print('Test Year {} Summary |'.format(test_year), 'Bets made:', bets_made, '| Bets won:', bets_won, '| Bets lost:', bets_lost, '| Bets pushed:', bets_push, '| Game count:', games, '| Bet win rate:', win_rate, '| Final bankroll:', profit)
# Out:
# ---------------------------------------
# THRESHOLD: 6
# Test Year 2019 Summary | Bets made: 104 | Bets won: 46 | Bets lost: 57 | Bets pushed: 1 | Game count: 997 | Bet win rate: 0.45 | Final bankroll: -1560.0
# Test Year 2020 Summary | Bets made: 164 | Bets won: 73 | Bets lost: 88 | Bets pushed: 3 | Game count: 1029 | Bet win rate: 0.45 | Final bankroll: -2230.0
# Test Year 2021 Summary | Bets made: 123 | Bets won: 55 | Bets lost: 66 | Bets pushed: 2 | Game count: 1180 | Bet win rate: 0.45 | Final bankroll: -1650.0
# Test Year 2022 Summary | Bets made: 190 | Bets won: 91 | Bets lost: 95 | Bets pushed: 4 | Game count: 1074 | Bet win rate: 0.49 | Final bankroll: -1310.0
# ---------------------------------------
# THRESHOLD: 8
# Test Year 2019 Summary | Bets made: 32 | Bets won: 19 | Bets lost: 13 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.59 | Final bankroll: 410.0
# Test Year 2020 Summary | Bets made: 45 | Bets won: 19 | Bets lost: 25 | Bets pushed: 1 | Game count: 1029 | Bet win rate: 0.43 | Final bankroll: -790.0
# Test Year 2021 Summary | Bets made: 44 | Bets won: 24 | Bets lost: 19 | Bets pushed: 1 | Game count: 1180 | Bet win rate: 0.56 | Final bankroll: 260.0
# Test Year 2022 Summary | Bets made: 84 | Bets won: 41 | Bets lost: 41 | Bets pushed: 2 | Game count: 1074 | Bet win rate: 0.5 | Final bankroll: -410.0
# ---------------------------------------
# THRESHOLD: 10
# Test Year 2019 Summary | Bets made: 16 | Bets won: 9 | Bets lost: 7 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.56 | Final bankroll: 110.0
# Test Year 2020 Summary | Bets made: 9 | Bets won: 6 | Bets lost: 3 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.67 | Final bankroll: 240.0
# Test Year 2021 Summary | Bets made: 12 | Bets won: 5 | Bets lost: 7 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.42 | Final bankroll: -250.0
# Test Year 2022 Summary | Bets made: 35 | Bets won: 18 | Bets lost: 17 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.51 | Final bankroll: -80.0
# ---------------------------------------
# THRESHOLD: 12
# Test Year 2019 Summary | Bets made: 4 | Bets won: 2 | Bets lost: 2 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.5 | Final bankroll: -20.0
# Test Year 2020 Summary | Bets made: 5 | Bets won: 4 | Bets lost: 1 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.8 | Final bankroll: 260.0
# Test Year 2021 Summary | Bets made: 3 | Bets won: 1 | Bets lost: 2 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.33 | Final bankroll: -110.0
# Test Year 2022 Summary | Bets made: 16 | Bets won: 9 | Bets lost: 7 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.56 | Final bankroll: 110.0
# ---------------------------------------
# THRESHOLD: 14
# Test Year 2019 Summary | Bets made: 1 | Bets won: 1 | Bets lost: 0 | Bets pushed: 0 | Game count: 997 | Bet win rate: 1.0 | Final bankroll: 90.0
# Test Year 2020 Summary | Bets made: 4 | Bets won: 4 | Bets lost: 0 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 1.0 | Final bankroll: 360.0
# Test Year 2021 Summary | Bets made: 1 | Bets won: 1 | Bets lost: 0 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 1.0 | Final bankroll: 90.0
# Test Year 2022 Summary | Bets made: 2 | Bets won: 1 | Bets lost: 1 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.5 | Final bankroll: -10.0

# %% [markdown]
# Result interpretation: the maximum return is generated when we set our THRESHOLD value to 8 (meaning our model differs from the projected line by 8 or more points). Our bet accuracy tends to increase with this THRESHOLD value, but the number of bets that the algorithm makes continues to decrease.
#
# Let's try out some other models.

# %% [markdown]
# # Model 2: Neural Network
#
# Again, the first step will be to identify the optimal hyper-parameters for the network. Then we will build our models and simulate the profit and loss.

# %%
# import numpy as np
# import pandas as pd
# from sklearn.pipeline import Pipeline
# from sklearn.neural_network import MLPRegressor
# from sklearn.preprocessing import StandardScaler, RobustScaler, PowerTransformer
# from sklearn.model_selection import GridSearchCV
# from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# train_df = pd.read_csv('train_df.csv')

# def custom_time_series_splits(df, season_col='SEASON'):
#     for season in range(min(train_df.SEASON), max(train_df.SEASON)): 
#         train_indices = df[df[season_col] == season].index.values
#         test_indices = df[df[season_col] == season + 1].index.values
#         # Randomly sample 50% of the test indices
#         test_indices = np.random.choice(test_indices, size=int(0.50 * len(test_indices)), replace=False)
#         yield train_indices, test_indices

# X = train_df.drop(['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'], axis=1)
# y = train_df['HOME PLUS MINUS']

# # Scale the features because MLP is sensitive to feature scaling
# scaler = StandardScaler()
# X = scaler.fit_transform(X)

# # Create an MLPRegressor object
# MAX_ITER = 5000
# mlp = MLPRegressor(random_state=42, max_iter=MAX_ITER)  # Increased max_iter and increased tolerance to try to ensure convergence

# # Define the parameter grid for MLP
# param_grid = {
#     'hidden_layer_sizes': [(50), (50, 50), (100), (100,100), (200), (200,200)],  # Test different neural net architectures
#     'activation': ['tanh','relu'],
#     'solver': ['adam'],
#     'alpha': [0.01, 0.1, 0.25],  # Regularization term
#     'learning_rate_init': [0.00001, 0.0001, 0.001],
#     'learning_rate': ['adaptive']
# }

# # Define a scorer (using MSE)
# scorer = make_scorer(mean_squared_error, greater_is_better=False)

# # Use the generator for custom CV splits
# cv_splits = list(custom_time_series_splits(train_df))

# grid_search = GridSearchCV(estimator=mlp, param_grid=param_grid, cv=cv_splits, scoring=scorer, n_jobs=-1)
# grid_search.fit(X, y)

# # Obtain the cross-validation results
# cv_results = grid_search.cv_results_

# # Print the average validation score (MSE) for each parameter combination
# for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
#     print(f"Average Loss (MSE): {-mean_score:.4f} | Parameters: {params}")

# best_params = grid_search.best_params_
# print(f"\nBest parameters: {best_params}")

# %%
# NN attempt 2 with different scaling mechanisms

import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler, RobustScaler, PowerTransformer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

train_df = pd.read_csv('train_df.csv')

def custom_time_series_splits(df, season_col='SEASON'):
    for season in range(min(train_df.SEASON), max(train_df.SEASON)): 
        train_indices = df[df[season_col] == season].index.values
        test_indices = df[df[season_col] == season + 1].index.values
        # Randomly sample 50% of the test indices
        test_indices = np.random.choice(test_indices, size=int(1 * len(test_indices)), replace=False)
        yield train_indices, test_indices

X = train_df.drop(['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'], axis=1)
y = train_df['HOME PLUS MINUS']

# Scale the features because MLP is sensitive to feature scaling. We want to try a few different scaling options in our grid search.
# First, Define a pipeline
pipe = Pipeline([
    ('scaler', StandardScaler()),  # Placeholder, will be set by GridSearchCV
    ('mlp', MLPRegressor(max_iter=5000, random_state=42, tol=0.1))
])

# Define the parameter grid for MLP
param_grid = {
    'scaler': [StandardScaler(), RobustScaler(), PowerTransformer()],
    'mlp__hidden_layer_sizes': [(50, 50), (50, 100), (100,100), (100,200)],  # Test different neural net architectures
    'mlp__activation': ['relu','tanh'],
    'mlp__solver': ['adam'],
    'mlp__alpha': [0.1, 1, 10],  # Regularization term
    'mlp__learning_rate_init': [0.00001, 0.0001, 0.001],
    'mlp__learning_rate': ['adaptive', 'constant']
}

# Define a scorer (using MSE)
scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Use the generator for custom CV splits
cv_splits = list(custom_time_series_splits(train_df))

grid_search = GridSearchCV(pipe, param_grid=param_grid, cv=cv_splits, scoring=scorer, n_jobs=-1)
grid_search.fit(X, y)

# Obtain the cross-validation results
cv_results = grid_search.cv_results_

# Print the average validation score (MSE) for each parameter combination
for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
    print(f"Average Loss (MSE): {-mean_score:.4f} | Parameters: {params}")

best_params = grid_search.best_params_
print(f"\nBest parameters: {best_params}")
# Out:
# Average Loss (MSE): 210.4478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1875 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4714 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0928 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.3789 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9386 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 403.8140 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 378.1334 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 400.2527 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.4478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1875 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4714 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0928 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.3789 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9386 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 403.8140 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 378.1334 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 400.2527 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3740 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0689 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4422 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6867 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.7822 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.6946 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 405.7826 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 456.9672 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 415.6991 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3740 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0689 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4422 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6867 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.7822 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.6946 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 405.7826 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 456.9672 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 415.6991 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.6978 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.2295 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6496 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.5517 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.8463 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.1228 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 405.3083 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 407.6579 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 402.6151 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.6978 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.2295 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6496 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.5517 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.8463 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.1228 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 405.3083 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 407.6579 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 402.6151 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.1037 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.6824 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.1117 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.7992 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.5785 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.4884 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 400.5660 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 376.3478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 372.2967 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.1037 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.6824 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.1117 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.7992 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.5785 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.4884 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 400.5660 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 376.3478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 372.2967 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 0.1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.4478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1875 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4714 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0855 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.3709 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9367 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 407.6564 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 344.6515 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 395.1729 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.4478 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1875 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4714 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0855 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.3709 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9367 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 407.6564 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 344.6515 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 395.1729 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3740 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0689 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4422 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6732 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.8121 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.6838 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 408.8479 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 438.7653 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 399.5792 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3740 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0689 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4422 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6732 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.8121 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.6838 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 408.8479 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 438.7653 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 399.5792 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.6979 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.2295 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6496 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.5464 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.9491 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.1160 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 398.2096 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 415.5604 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 399.8980 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.6979 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.2295 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6496 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.5464 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.9491 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.1160 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 398.2096 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 415.5604 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 399.8980 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.1040 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.6863 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.1119 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.7902 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.6511 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.4713 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 391.6731 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 398.0262 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 370.2548 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.1040 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.6863 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.1119 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.7902 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.6511 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.4713 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 391.6731 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 398.0262 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 370.2548 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 1, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.4492 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1890 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4729 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0907 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.4033 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9421 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 382.9610 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 324.0015 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 385.3112 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.4492 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.1890 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.4729 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.0907 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 190.4033 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.9421 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 382.9610 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 324.0015 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 385.3112 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3769 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0719 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4451 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6788 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.7157 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.7044 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 377.6448 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 341.1237 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 376.2360 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 213.3769 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.0719 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 213.4451 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 184.6788 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 189.7157 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 184.7044 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 377.6448 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 341.1237 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 376.2360 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.7019 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.1911 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6537 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.4864 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.8874 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.0932 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 381.1102 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 370.5930 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 376.0705 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 210.7019 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 211.1911 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 210.6537 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.4864 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.8874 | Parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# ...
# Average Loss (MSE): 209.5720 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.0345 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 209.6628 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 183.7257 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.2752 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.6526 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 388.7804 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 380.9289 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 390.6228 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 50), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 214.9107 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.9156 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 214.9298 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 183.6419 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.8787 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.7595 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 412.1705 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 387.6142 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 411.1550 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 214.9107 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 213.9156 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 214.9298 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 183.6419 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 185.8787 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 183.7595 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 412.1705 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 387.6142 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 411.1550 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (50, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 209.4431 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.1381 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 209.2865 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 182.1901 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.3812 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.6071 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 367.7852 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 351.6577 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 359.6170 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 209.4431 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 210.1381 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 209.2865 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 182.1901 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.3812 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.6071 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 367.7852 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 351.6577 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 359.6170 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 208.0802 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 207.8754 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 208.3068 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.8120 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.2100 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.2152 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 386.3174 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 375.5202 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 364.4603 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 208.0802 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 207.8754 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 208.3068 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 1e-05, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 181.8120 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 183.2100 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 181.2152 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
# Average Loss (MSE): 386.3174 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': StandardScaler()}
# Average Loss (MSE): 375.5202 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': RobustScaler()}
# Average Loss (MSE): 364.4603 | Parameters: {'mlp__activation': 'tanh', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 200), 'mlp__learning_rate': 'constant', 'mlp__learning_rate_init': 0.001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}
#
# Best parameters: {'mlp__activation': 'relu', 'mlp__alpha': 10, 'mlp__hidden_layer_sizes': (100, 100), 'mlp__learning_rate': 'adaptive', 'mlp__learning_rate_init': 0.0001, 'mlp__solver': 'adam', 'scaler': PowerTransformer()}

# %%
# What do the individual year MSE values look like? How much variance is there?
best_index = grid_search.best_index_

# Extract individual test scores for the best parameters
test_scores = []
for i in range(len(cv_splits)):  
    split_score_key = f"split{i}_test_score"
    test_scores.append(np.abs(grid_search.cv_results_[split_score_key][best_index]))

print(f"Individual test scores for the best parameters: {test_scores}")
print(f"Average MSE: {np.abs(np.mean(test_scores))}")
# Out:
# Individual test scores for the best parameters: [171.2518999480216, 166.30640118246976, 176.70143688281576, 167.1062586304809, 200.15068006639126, 216.3076761772237, 169.82776654548795]
# Average MSE: 181.09315991898444

# %%
from sklearn.pipeline import Pipeline

def train_and_validate_models(df, best_params, best_scaler, season_col='SEASON'):
    trained_models = []
    validation_scores = []

    # Define the range of starting seasons for training data (2015 to 2018 inclusive)
    for start_season in range(2015, 2019):
        # Split the data based on the seasons
        train_data = df[(df[season_col] >= start_season) & (df[season_col] <= start_season + 3)]
        test_data = df[df[season_col] == start_season + 4]

        # Extract features and target variable
        X_train = train_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_train = train_data['HOME PLUS MINUS']

        X_test = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_test = test_data['HOME PLUS MINUS']

        # Setup a pipeline using best scaler and model parameters
        model = Pipeline([
            ('scaler', best_scaler),
            ('mlp', MLPRegressor(**best_params, random_state=42))
        ])

        # Train the model using best hyperparameters identified previously
        model.fit(X_train, y_train)

        # Validate the model on the test set
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)

        # Store the trained model and validation score
        trained_models.append(model)
        validation_scores.append(mse)

        print(f"Trained for seasons {start_season}-{start_season+3}, MSE on season {start_season+4}: {mse:.4f}")

    return trained_models, validation_scores

# Extract the best parameters and scaler from GridSearchCV results
best_params = {k.replace('mlp__', ''): v for k, v in grid_search.best_params_.items() if 'mlp__' in k}
best_scaler = grid_search.best_params_['scaler']

# Call the function with the best parameters and the best scaler
nn_models, nn_scores = train_and_validate_models(train_df, best_params, best_scaler)
# Out:
# Trained for seasons 2015-2018, MSE on season 2019: 172.9143
# Trained for seasons 2016-2019, MSE on season 2020: 194.9238
# Trained for seasons 2017-2020, MSE on season 2021: 213.1592
# Trained for seasons 2018-2021, MSE on season 2022: 168.0938

# %%
START_YEAR = 2015
BET_AMOUNT = 100
TAKE_RATE = 0.1

# Set your margin for level of confidence (higher value means the model needs to be more confident in order to place a bet)
# THRESHOLD = 4

for THRESHOLD in [5,6,7,8,9,10]:
    print('---------------------------------------')
    print('THRESHOLD:', THRESHOLD)


    # Loop through all models constructed and create a dataframe with the bet decision and the bet outcome
    for i, model in enumerate(nn_models):
        test_year = START_YEAR + 4 + i
        #print('Test Year:', test_year)
        test_data = train_df[train_df['SEASON'] == test_year].reset_index(drop=True)

        # Prepare data for inference
        X = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])

        # Create your vector of predictions
        y_pred = model.predict(X)

        decisions = []
        outcomes = []
        bets_made = 0 
        bets_won = 0
        bets_lost = 0
        bets_push = 0
        games = len(test_data)
        profit = 0
        net_bets_made = 0

        for index, row in test_data.iterrows():

            bet = None
            home_favored_bet_home = False 
            home_favored_bet_away = False
            away_favored_bet_home = False
            away_favored_bet_away = False
            no_favorite_bet_home = False
            no_favorite_bet_away = False 
            
            # Bet when home is favored AND you think home team will outperform the spread by THRESHOLD
            home_favored_bet_home = row['HOME SPREAD'] < 0 and (y_pred[index] - THRESHOLD > abs(row['HOME SPREAD']))

            # Bet when home is favored BUT you think the away team will outperform the spread by THRESHOLD
            home_favored_bet_away = row['HOME SPREAD'] < 0 and ((y_pred[index] < 0 and (abs(row['HOME SPREAD'] + y_pred[index]) > THRESHOLD)) or (y_pred[index] >= 0 and y_pred[index] + THRESHOLD < abs(row['HOME SPREAD'])))

            # Bet when away is favored BUT you think the home team will outperform the spread (you think home team wins outright, by at least a particular relative margin OR you think the away team wins, but not by as much as the market thinks)
            away_favored_bet_home = row['HOME SPREAD'] > 0 and (((y_pred[index] > 0 and y_pred[index] + row['HOME SPREAD'] > THRESHOLD)) or ((y_pred[index] <= 0) and abs(y_pred[index]) + THRESHOLD < row['HOME SPREAD']))

            # Bet when away is favored AND you think away team will outperform the spread by THRESHOLD
            away_favored_bet_away = row['HOME SPREAD'] > 0 and y_pred[index] < 0 and (abs(y_pred[index]) - THRESHOLD > row['HOME SPREAD'])

            # Bet when there is no favorite, but you think HOME will win by more than THRESHOLD
            no_favorite_bet_home = row['HOME SPREAD'] == 0 and (y_pred[index] > THRESHOLD)

            # Bet when there is no favorite, but you think AWAY will win by more than THRESHOLD
            no_favorite_bet_away = row['HOME SPREAD'] == 0 and (abs(y_pred[index]) > THRESHOLD)


            # Bet home or away
            if home_favored_bet_home or away_favored_bet_home or no_favorite_bet_home:
                bet = 'Bet on Home'
            elif home_favored_bet_away or away_favored_bet_away or no_favorite_bet_away:
                bet = 'Bet on Away'
            else: 
                bet = 'No Bet'

            # Outcomes
            if bet == 'Bet on Home':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']:  # HOME COVERED THE SPREAD
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
                else:
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                    
            elif bet == 'Bet on Away':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']: # HOME COVERED THE SPREAD
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                else: 
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
            else: 
                outcome = 'No Bet Placed'

            decisions.append(bet)
            outcomes.append(outcome)        
                        
            #print('Market home plus minus:', -row['HOME SPREAD'], '| Predicted home plus minus:', round(y_pred[index],1), '| Bet:', bet, ' | Actual home plus minus:', row['HOME PLUS MINUS'], '| Bet outcome:', outcome)

        if net_bets_made == 0:
            win_rate = 0
        else:
            win_rate = round(bets_won / net_bets_made, 2)

        print('Test Year {} Summary |'.format(test_year), 'Bets made:', bets_made, '| Bets won:', bets_won, '| Bets lost:', bets_lost, '| Bets pushed:', bets_push, '| Game count:', games, '| Bet win rate:', win_rate, '| Final bankroll:', profit)
# Out:
# ---------------------------------------
# THRESHOLD: 5
# Test Year 2019 Summary | Bets made: 177 | Bets won: 88 | Bets lost: 86 | Bets pushed: 3 | Game count: 997 | Bet win rate: 0.51 | Final bankroll: -680.0
# Test Year 2020 Summary | Bets made: 240 | Bets won: 121 | Bets lost: 116 | Bets pushed: 3 | Game count: 1029 | Bet win rate: 0.51 | Final bankroll: -710.0
# Test Year 2021 Summary | Bets made: 277 | Bets won: 137 | Bets lost: 136 | Bets pushed: 4 | Game count: 1180 | Bet win rate: 0.5 | Final bankroll: -1270.0
# Test Year 2022 Summary | Bets made: 301 | Bets won: 143 | Bets lost: 153 | Bets pushed: 5 | Game count: 1074 | Bet win rate: 0.48 | Final bankroll: -2430.0
# ---------------------------------------
# THRESHOLD: 6
# Test Year 2019 Summary | Bets made: 115 | Bets won: 55 | Bets lost: 59 | Bets pushed: 1 | Game count: 997 | Bet win rate: 0.48 | Final bankroll: -950.0
# Test Year 2020 Summary | Bets made: 160 | Bets won: 81 | Bets lost: 78 | Bets pushed: 1 | Game count: 1029 | Bet win rate: 0.51 | Final bankroll: -510.0
# Test Year 2021 Summary | Bets made: 174 | Bets won: 84 | Bets lost: 86 | Bets pushed: 4 | Game count: 1180 | Bet win rate: 0.49 | Final bankroll: -1040.0
# Test Year 2022 Summary | Bets made: 211 | Bets won: 107 | Bets lost: 100 | Bets pushed: 4 | Game count: 1074 | Bet win rate: 0.52 | Final bankroll: -370.0
# ---------------------------------------
# THRESHOLD: 7
# Test Year 2019 Summary | Bets made: 64 | Bets won: 31 | Bets lost: 33 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.48 | Final bankroll: -510.0
# Test Year 2020 Summary | Bets made: 102 | Bets won: 58 | Bets lost: 44 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.57 | Final bankroll: 820.0
# Test Year 2021 Summary | Bets made: 102 | Bets won: 52 | Bets lost: 49 | Bets pushed: 1 | Game count: 1180 | Bet win rate: 0.51 | Final bankroll: -220.0
# Test Year 2022 Summary | Bets made: 153 | Bets won: 80 | Bets lost: 70 | Bets pushed: 3 | Game count: 1074 | Bet win rate: 0.53 | Final bankroll: 200.0
# ---------------------------------------
# THRESHOLD: 8
# Test Year 2019 Summary | Bets made: 48 | Bets won: 25 | Bets lost: 23 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.52 | Final bankroll: -50.0
# Test Year 2020 Summary | Bets made: 65 | Bets won: 43 | Bets lost: 22 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.66 | Final bankroll: 1670.0
# Test Year 2021 Summary | Bets made: 61 | Bets won: 32 | Bets lost: 29 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.52 | Final bankroll: -20.0
# Test Year 2022 Summary | Bets made: 100 | Bets won: 52 | Bets lost: 45 | Bets pushed: 3 | Game count: 1074 | Bet win rate: 0.54 | Final bankroll: 180.0
# ---------------------------------------
# THRESHOLD: 9
# Test Year 2019 Summary | Bets made: 27 | Bets won: 14 | Bets lost: 13 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.52 | Final bankroll: -40.0
# Test Year 2020 Summary | Bets made: 37 | Bets won: 25 | Bets lost: 12 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.68 | Final bankroll: 1050.0
# Test Year 2021 Summary | Bets made: 46 | Bets won: 23 | Bets lost: 23 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.5 | Final bankroll: -230.0
# Test Year 2022 Summary | Bets made: 69 | Bets won: 37 | Bets lost: 31 | Bets pushed: 1 | Game count: 1074 | Bet win rate: 0.54 | Final bankroll: 230.0
# ---------------------------------------
# THRESHOLD: 10
# Test Year 2019 Summary | Bets made: 14 | Bets won: 8 | Bets lost: 6 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.57 | Final bankroll: 120.0
# Test Year 2020 Summary | Bets made: 21 | Bets won: 14 | Bets lost: 7 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.67 | Final bankroll: 560.0
# Test Year 2021 Summary | Bets made: 24 | Bets won: 10 | Bets lost: 14 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.42 | Final bankroll: -500.0
# Test Year 2022 Summary | Bets made: 45 | Bets won: 27 | Bets lost: 17 | Bets pushed: 1 | Game count: 1074 | Bet win rate: 0.61 | Final bankroll: 730.0

# %% [markdown]
# # Model 3: XGBoost

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error

train_df = pd.read_csv('train_df.csv')

def custom_time_series_splits(df, season_col='SEASON'):
    for season in range(min(train_df.SEASON), max(train_df.SEASON)):  # For seasons 2015 to 2021
        train_indices = df[df[season_col] == season].index.values
        test_indices = df[df[season_col] == season + 1].index.values
        # Randomly sample 50% of the test indices
        test_indices = np.random.choice(test_indices, size=int(1 * len(test_indices)), replace=False)
        
        yield train_indices, test_indices

X = train_df.drop(['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'], axis=1)
y = train_df['HOME PLUS MINUS']

# Create an XGBoost regressor object
xgb_regressor = xgb.XGBRegressor(random_state=42, objective='reg:squarederror')

# Define the parameter grid for XGBoost
param_grid = {
    'n_estimators': [100, 500],
    'max_depth': [3, 5],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.8, 1],
    'colsample_bytree': [0.8, 1],
    'gamma': [0, 0.1, 0.2],
    'reg_alpha': [0, 0.1, 1],
    'reg_lambda': [1, 1.5, 2]
}

# Define a scorer (using MSE)
scorer = make_scorer(mean_squared_error, greater_is_better=False)

# Use the generator for custom CV splits
cv_splits = list(custom_time_series_splits(train_df))

grid_search = GridSearchCV(estimator=xgb_regressor, param_grid=param_grid, cv=cv_splits, scoring=scorer, n_jobs=3)
grid_search.fit(X, y)

# Obtain the cross-validation results
cv_results = grid_search.cv_results_

# Print the average validation score (MSE) for each parameter combination
for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
    print(f"Average Loss (MSE): {-mean_score:.4f} | Parameters: {params}")

best_params = grid_search.best_params_
print(f"\nBest parameters: {best_params}")
# Out:
# Average Loss (MSE): 189.2777 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3559 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2690 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3090 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.2944 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.4122 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.2797 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.4006 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2731 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3538 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.2805 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.4460 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.2991 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3091 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2790 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3858 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.3070 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.3071 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.4996 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3576 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.1628 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.7071 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 187.8486 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.9282 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.6090 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.7772 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.0268 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.9018 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 187.7848 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.9500 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.5263 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.4918 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.1248 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.7448 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 187.7494 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.7454 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.8146 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.9707 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.7357 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.8332 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.7375 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.7958 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.7049 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 191.1032 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.7255 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 191.0037 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.7526 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.9284 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.6524 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 191.0658 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.7847 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.9225 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.8016 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.5927 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 191.8963 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 195.1989 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 191.4859 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 194.6128 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 191.2941 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 194.1584 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 191.6767 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 195.1626 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 191.6426 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 194.5787 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 191.2331 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 194.2009 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 191.4185 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 194.6033 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 191.4035 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 194.5507 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 191.1173 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 193.6838 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.6001 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 191.5252 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.7010 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.9461 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.0897 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.8785 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.6667 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 191.6532 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.5936 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 191.2116 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.3152 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 191.0081 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.8004 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 191.3266 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.6492 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 191.6793 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.7392 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 191.0958 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 207.6621 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 213.1587 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 207.3982 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 210.0050 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 206.6908 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 209.2182 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 209.0136 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 212.5049 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 207.7007 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 210.7671 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 206.9279 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 209.3484 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 207.9537 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 213.5117 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 207.1358 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 209.7963 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 207.5393 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 210.4499 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 195.1948 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 196.7734 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 194.6013 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 197.3867 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 193.5112 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 196.9485 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 196.0542 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 197.2931 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 194.7946 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 196.8202 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 192.8962 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 196.4138 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 194.7201 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 196.3420 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 195.4141 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 196.1451 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 193.4306 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 196.5669 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 209.9023 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 214.7122 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 209.7487 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 215.1764 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 208.0114 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 212.6549 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 211.5909 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 214.3900 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 209.7424 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 214.5971 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 208.2784 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 213.2683 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 209.0155 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 213.2190 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 210.3877 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 212.4380 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 207.5607 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 212.8091 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 200.1601 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 198.3058 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 197.7030 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 197.3329 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 196.1456 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 197.6232 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 200.0933 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 199.6244 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 197.6032 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 197.2851 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 195.4337 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 197.5956 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 198.8863 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 198.3756 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 197.8870 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 196.5823 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 196.1841 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 197.6794 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 225.9156 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 230.1584 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 223.9944 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 227.9077 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 224.3559 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 224.9567 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 225.1012 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 232.2835 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 225.1444 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 227.4269 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 223.3592 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 223.5669 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 225.8541 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 229.4039 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 221.6568 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 223.8055 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 222.7527 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 224.6349 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 205.5145 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 204.6740 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 204.4691 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 205.1863 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 202.5796 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 204.3037 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 202.5912 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 203.9296 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 202.4254 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 204.7538 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 202.6340 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 205.2061 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 204.2327 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 202.5322 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 205.0302 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 205.8071 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 201.0356 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 203.7740 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 219.2660 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 222.7274 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 218.7554 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 221.4195 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 216.5312 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 220.2318 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 214.5642 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 221.9646 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 214.7472 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 222.8526 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 215.8919 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 220.8878 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 217.2045 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 219.1249 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 217.2929 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 221.2878 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 214.8654 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 220.4588 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.2777 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3559 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2690 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3090 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.2944 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.4122 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.2797 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.4006 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2731 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3538 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.2805 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.4460 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 189.2991 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3091 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 189.2790 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.3858 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 189.3070 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.3071 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.4996 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.3367 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.1577 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.6410 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 187.8494 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.9284 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.6092 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.7517 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.0267 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 190.8137 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 187.7859 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 190.9388 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 188.5263 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 190.4408 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 188.1248 | Parameters: {'colsample_bytree': 0.8, 'gamma': 0.1, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# ...
# Average Loss (MSE): 210.8090 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 216.1378 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 208.6722 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 214.6967 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 211.1217 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 216.2475 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 210.6397 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 215.0672 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 209.1966 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 214.4497 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 199.1938 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 198.3363 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 197.7665 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 198.2294 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 199.2203 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 198.0931 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 198.9626 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 198.8752 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 198.1073 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 197.4676 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 197.5491 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 198.4886 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 198.3624 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 199.2664 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 197.5076 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 200.0903 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 198.4214 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 198.1387 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 228.0533 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 232.0647 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 227.7531 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 229.1205 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 226.8967 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 227.4249 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 227.3605 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 229.8588 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 225.1438 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 228.1116 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 225.0712 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 227.5197 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 224.7306 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 228.1507 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 224.8862 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 228.4901 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 225.3822 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 225.4604 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 208.1173 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 206.3067 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 203.5882 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 207.8593 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 204.8053 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 205.6249 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 205.7469 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 206.3787 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 203.7077 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 207.6008 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 203.1684 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 206.5865 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 206.6801 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 206.9217 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 203.6545 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 205.3706 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 203.8189 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 204.1676 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 223.4153 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 225.1486 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 216.0154 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 223.4713 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 218.3648 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 222.5977 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 220.2715 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 225.4798 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 218.3501 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 223.9478 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 217.5282 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 225.4491 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 0.1, 'reg_lambda': 2, 'subsample': 1}
# Average Loss (MSE): 220.3324 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 0.8}
# Average Loss (MSE): 223.7768 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1, 'subsample': 1}
# Average Loss (MSE): 216.5781 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 0.8}
# Average Loss (MSE): 221.8991 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 1.5, 'subsample': 1}
# Average Loss (MSE): 216.9022 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}
# Average Loss (MSE): 221.7662 | Parameters: {'colsample_bytree': 1, 'gamma': 0.2, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 1}
#
# Best parameters: {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500, 'reg_alpha': 1, 'reg_lambda': 2, 'subsample': 0.8}

# %%
# What do the individual year MSE values look like? How much variance is there?
best_index = grid_search.best_index_

# Extract individual test scores for the best parameters
test_scores = []
for i in range(len(cv_splits)):  
    split_score_key = f"split{i}_test_score"
    test_scores.append(np.abs(grid_search.cv_results_[split_score_key][best_index]))

print(f"Individual test scores for the best parameters: {test_scores}")
print(f"Average MSE: {np.abs(np.mean(test_scores))}")

# best was -193
# Out:
# Individual test scores for the best parameters: [175.7677567191533, 170.14983697940517, 179.57394853183948, 173.84372050821688, 208.72424331659263, 224.00361434710646, 182.18299647101057]
# Average MSE: 187.74944526761777

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error

def train_and_validate_models(df, best_params, season_col='SEASON'):
    trained_models = []
    validation_scores = []

    # Define the range of starting seasons for training data (2015 to 2018 inclusive)
    for start_season in range(2015, 2019):
        # Split the data based on the seasons
        train_data = df[(df[season_col] >= start_season) & (df[season_col] <= start_season + 3)]
        test_data = df[df[season_col] == start_season + 4]

        # Extract features and target variable
        X_train = train_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_train = train_data['HOME PLUS MINUS']

        X_test = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
        y_test = test_data['HOME PLUS MINUS']

        # Train the model using best hyperparameters identified previously
        model = xgb.XGBRegressor(**best_params, random_state=42)
        model.fit(X_train, y_train)

        # Validate the model on the test set
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)

        # Store the trained model and validation score
        trained_models.append(model)
        validation_scores.append(mse)

        print(f"Trained for seasons {start_season}-{start_season+3}, MSE on season {start_season+4}: {mse:.4f}")

    return trained_models, validation_scores

# Call the function
xgb_models, xgb_scores = train_and_validate_models(train_df, best_params)
# Out:
# Trained for seasons 2015-2018, MSE on season 2019: 170.6674
# Trained for seasons 2016-2019, MSE on season 2020: 199.2154
# Trained for seasons 2017-2020, MSE on season 2021: 213.6061
# Trained for seasons 2018-2021, MSE on season 2022: 168.4851

# %%
START_YEAR = 2015
BET_AMOUNT = 100
TAKE_RATE = 0.1

# Set your margin for level of confidence (higher value means the model needs to be more confident in order to place a bet)
# THRESHOLD = 4

for THRESHOLD in [0,5,10,15]:
    print('---------------------------------------')
    print('THRESHOLD:', THRESHOLD)


    # Loop through all models constructed and create a dataframe with the bet decision and the bet outcome
    for i, model in enumerate(xgb_models):
        test_year = START_YEAR + 4 + i
        #print('Test Year:', test_year)
        test_data = train_df[train_df['SEASON'] == test_year].reset_index(drop=True)

        # Prepare data for inference
        X = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])

        # Create your vector of predictions
        y_pred = model.predict(X)

        decisions = []
        outcomes = []
        bets_made = 0 
        bets_won = 0
        bets_lost = 0
        bets_push = 0
        games = len(test_data)
        profit = 0
        net_bets_made = 0

        for index, row in test_data.iterrows():

            bet = None
            home_favored_bet_home = False 
            home_favored_bet_away = False
            away_favored_bet_home = False
            away_favored_bet_away = False
            no_favorite_bet_home = False
            no_favorite_bet_away = False 
            
            # Bet when home is favored AND you think home team will outperform the spread by THRESHOLD
            home_favored_bet_home = row['HOME SPREAD'] < 0 and (y_pred[index] - THRESHOLD > abs(row['HOME SPREAD']))

            # Bet when home is favored BUT you think the away team will outperform the spread by THRESHOLD
            home_favored_bet_away = row['HOME SPREAD'] < 0 and ((y_pred[index] < 0 and (abs(row['HOME SPREAD'] + y_pred[index]) > THRESHOLD)) or (y_pred[index] >= 0 and y_pred[index] + THRESHOLD < abs(row['HOME SPREAD'])))

            # Bet when away is favored BUT you think the home team will outperform the spread (you think home team wins outright, by at least a particular relative margin OR you think the away team wins, but not by as much as the market thinks)
            away_favored_bet_home = row['HOME SPREAD'] > 0 and (((y_pred[index] > 0 and y_pred[index] + row['HOME SPREAD'] > THRESHOLD)) or ((y_pred[index] <= 0) and abs(y_pred[index]) + THRESHOLD < row['HOME SPREAD']))

            # Bet when away is favored AND you think away team will outperform the spread by THRESHOLD
            away_favored_bet_away = row['HOME SPREAD'] > 0 and y_pred[index] < 0 and (abs(y_pred[index]) - THRESHOLD > row['HOME SPREAD'])

            # Bet when there is no favorite, but you think HOME will win by more than THRESHOLD
            no_favorite_bet_home = row['HOME SPREAD'] == 0 and (y_pred[index] > THRESHOLD)

            # Bet when there is no favorite, but you think AWAY will win by more than THRESHOLD
            no_favorite_bet_away = row['HOME SPREAD'] == 0 and (abs(y_pred[index]) > THRESHOLD)


            # Bet home or away
            if home_favored_bet_home or away_favored_bet_home or no_favorite_bet_home:
                bet = 'Bet on Home'
            elif home_favored_bet_away or away_favored_bet_away or no_favorite_bet_away:
                bet = 'Bet on Away'
            else: 
                bet = 'No Bet'

            # Outcomes
            if bet == 'Bet on Home':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']:  # HOME COVERED THE SPREAD
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
                else:
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                    
            elif bet == 'Bet on Away':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']: # HOME COVERED THE SPREAD
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                else: 
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
            else: 
                outcome = 'No Bet Placed'

            decisions.append(bet)
            outcomes.append(outcome)        
                        
            #print('Market home plus minus:', -row['HOME SPREAD'], '| Predicted home plus minus:', round(y_pred[index],1), '| Bet:', bet, ' | Actual home plus minus:', row['HOME PLUS MINUS'], '| Bet outcome:', outcome)

        if net_bets_made == 0:
            win_rate = 0
        else:
            win_rate = round(bets_won / net_bets_made, 2)

        print('Test Year {} Summary |'.format(test_year), 'Bets made:', bets_made, '| Bets won:', bets_won, '| Bets lost:', bets_lost, '| Bets pushed:', bets_push, '| Game count:', games, '| Bet win rate:', win_rate, '| Final bankroll:', profit)
# Out:
# ---------------------------------------
# THRESHOLD: 0
# Test Year 2019 Summary | Bets made: 997 | Bets won: 490 | Bets lost: 489 | Bets pushed: 18 | Game count: 997 | Bet win rate: 0.5 | Final bankroll: -4800.0
# Test Year 2020 Summary | Bets made: 1029 | Bets won: 512 | Bets lost: 504 | Bets pushed: 13 | Game count: 1029 | Bet win rate: 0.5 | Final bankroll: -4320.0
# Test Year 2021 Summary | Bets made: 1180 | Bets won: 538 | Bets lost: 625 | Bets pushed: 17 | Game count: 1180 | Bet win rate: 0.46 | Final bankroll: -14080.0
# Test Year 2022 Summary | Bets made: 1074 | Bets won: 509 | Bets lost: 555 | Bets pushed: 10 | Game count: 1074 | Bet win rate: 0.48 | Final bankroll: -9690.0
# ---------------------------------------
# THRESHOLD: 5
# Test Year 2019 Summary | Bets made: 134 | Bets won: 67 | Bets lost: 67 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.5 | Final bankroll: -670.0
# Test Year 2020 Summary | Bets made: 228 | Bets won: 113 | Bets lost: 112 | Bets pushed: 3 | Game count: 1029 | Bet win rate: 0.5 | Final bankroll: -1030.0
# Test Year 2021 Summary | Bets made: 197 | Bets won: 93 | Bets lost: 101 | Bets pushed: 3 | Game count: 1180 | Bet win rate: 0.48 | Final bankroll: -1730.0
# Test Year 2022 Summary | Bets made: 287 | Bets won: 141 | Bets lost: 141 | Bets pushed: 5 | Game count: 1074 | Bet win rate: 0.5 | Final bankroll: -1410.0
# ---------------------------------------
# THRESHOLD: 10
# Test Year 2019 Summary | Bets made: 10 | Bets won: 6 | Bets lost: 4 | Bets pushed: 0 | Game count: 997 | Bet win rate: 0.6 | Final bankroll: 140.0
# Test Year 2020 Summary | Bets made: 14 | Bets won: 9 | Bets lost: 5 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.64 | Final bankroll: 310.0
# Test Year 2021 Summary | Bets made: 13 | Bets won: 8 | Bets lost: 5 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.62 | Final bankroll: 220.0
# Test Year 2022 Summary | Bets made: 37 | Bets won: 23 | Bets lost: 14 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.62 | Final bankroll: 670.0
# ---------------------------------------
# THRESHOLD: 15
# Test Year 2019 Summary | Bets made: 1 | Bets won: 1 | Bets lost: 0 | Bets pushed: 0 | Game count: 997 | Bet win rate: 1.0 | Final bankroll: 90.0
# Test Year 2020 Summary | Bets made: 4 | Bets won: 4 | Bets lost: 0 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 1.0 | Final bankroll: 360.0
# Test Year 2021 Summary | Bets made: 1 | Bets won: 1 | Bets lost: 0 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 1.0 | Final bankroll: 90.0
# Test Year 2022 Summary | Bets made: 3 | Bets won: 3 | Bets lost: 0 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 1.0 | Final bankroll: 270.0

# %% [markdown]
# # Model 4: Stacked Meta Model Using Linear Regression
#
# For each of our annual models (2018, 2019, 2020, 2021), predict the HOME PLUS MINUS using the values from the 3 base models (RF, NN, XGB). These predictions will generate a training dataset (features are base model predictions for a given game), where the target is the HOME PLUS MINUS (stacked model)

# %%
START_YEAR = 2015
num_years_modeled = len(rf_models)
stacked_df = pd.DataFrame()

for i in range(num_years_modeled):
    tmp_df = pd.DataFrame()
    test_year = START_YEAR + 4 + i
    test_data = train_df[train_df['SEASON'] == test_year].reset_index(drop=True)

    # Prepare data for inference
    X = test_data.drop(columns=['SEASON', 'DATE', 'HOME', 'AWAY', 'HOME_PRIOR_GAME_DATE', 'AWAY_PRIOR_GAME_DATE', 'HOME TEAM GP', 'AWAY TEAM GP', 'HOME SPREAD', 'HOME PLUS MINUS'])
    
    # Target values will be stored for training on the stacked model
    y = test_data['HOME PLUS MINUS']

    # Create your vector of predictions, to be used as features in the stacked model
    y_pred1 = rf_models[i].predict(X)
    y_pred2 = nn_models[i].predict(X)
    y_pred3 = xgb_models[i].predict(X)

    tmp_df['SEASON'], tmp_df['rf'], tmp_df['nn'], tmp_df['xgb'], tmp_df['HOME SPREAD'], tmp_df['HOME PLUS MINUS'] = test_data['SEASON'], y_pred1, y_pred2, y_pred3, test_data['HOME SPREAD'], y
    stacked_df = pd.concat([stacked_df, tmp_df], ignore_index=True)

stacked_df.head()
# Out:
#    SEASON        rf         nn       xgb  HOME SPREAD  HOME PLUS MINUS
# 0    2019  7.737118   7.738207  8.783263         -5.0              -14
# 1    2019  0.987922  -1.662380  0.387412          0.0                4
# 2    2019  0.987425  -3.000574 -0.178026          1.5              -20
# 3    2019  5.702579  10.033599  4.985899         -8.0               -2
# 4    2019  2.993093   4.219421  3.229630         -5.5               10

# %% [markdown]
# FYI: The 'SEASON' column here represents data in the year we are trying to predict. Therefore, the models that generated the rf, nn, and xgb predictions were trained on the 4 years PRIOR to 'SEASON'.
#
# Now, let's build a STACKED model for each season. Start by training a first META MODEL on 2019 data (What was the best linear combination of the 2019 RF / NN / XGB model weights, based on the actual result in 2019 games?)
#
# Then, use this 2019 STACKED META MODEL to make predictions on 2020 NBA games, etc.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import pandas as pd

seasons = sorted(stacked_df['SEASON'].unique())
coefficients_list = []
mse_list = []
mse_list2 = []
predictions_list = []
avg_predictions_list = []
meta_models = []

# Train on one season and test on the next (to see if our stacked model can outperform the base models)
for i in range(len(seasons) - 1):
    train = stacked_df[stacked_df['SEASON'] == seasons[i]]
    test = stacked_df[stacked_df['SEASON'] == seasons[i + 1]]

    X_train = train[['rf', 'nn', 'xgb']]
    y_train = train['HOME PLUS MINUS']

    X_test = test[['rf', 'nn', 'xgb']]
    y_test = test['HOME PLUS MINUS']

    meta_model = LinearRegression()
    meta_model.fit(X_train, y_train)
    
    # Store coefficients
    coefficients = meta_model.coef_
    coefficients_list.append(coefficients)

    # Predict using the meta-model on the test set and store predictions
    y_pred = meta_model.predict(X_test)
    avg_y_pred = (X_test['rf'] + X_test['nn'] + X_test['xgb']) / 3.0
    predictions_list.extend(y_pred.tolist())
    avg_predictions_list.extend(avg_y_pred.tolist())

    # Calculate and store MSE for this season's predictions
    mse = mean_squared_error(y_test, y_pred)
    mse2 = mean_squared_error(y_test, avg_y_pred)
    mse_list.append(mse)
    mse_list2.append(mse2)

    # Store the trained models
    meta_models.append(meta_model)

# DataFrames for coefficients and MSE
coeff_df = pd.DataFrame(coefficients_list, columns=['random_forest_coef', 'neural_network_coef', 'xgboost_coef'])
coeff_df['SEASON'] = seasons[0:3]
mse_df = pd.DataFrame({'SEASON': seasons[1:], 'MSE': mse_list, 'MSE V2': mse_list2})

print('-- Optimal Model Coefficients ---')
display(coeff_df)
print('-- Updated Loss Calculations on Subsequent Season ---')
display(mse_df)
# Out:
# -- Optimal Model Coefficients ---
#    random_forest_coef  neural_network_coef  xgboost_coef  SEASON
# 0            0.411091             0.270739      0.434990    2019
# 1            1.082348             0.648043     -0.315557    2020
# 2            0.469297             0.576307      0.008662    2021
# -- Updated Loss Calculations on Subsequent Season ---
#    SEASON         MSE      MSE V2
# 0    2020  194.360633  195.956411
# 1    2021  212.116781  210.920808
# 2    2022  166.319410  165.640390

# %% [markdown]
# The coefficients for the base models are not particularly consistent, but the mean square error values using the meta model predictions do out-perform all 3 individual base models individually, every year.
#
# Let's update our win-loss $ if we substitute in these meta model predictions for 2020, 2021, and 2022.

# %%
len(predictions_list), len(train_df[train_df['SEASON']==2020]) + len(train_df[train_df['SEASON']==2021]) + len(train_df[train_df['SEASON']==2022])
# Out:
# (3283, 3283)

# %%
stacked_df.head()
# Out:
#    SEASON        rf         nn       xgb  HOME SPREAD  HOME PLUS MINUS
# 0    2019  7.737118   7.738207  8.783263         -5.0              -14
# 1    2019  0.987922  -1.662380  0.387412          0.0                4
# 2    2019  0.987425  -3.000574 -0.178026          1.5              -20
# 3    2019  5.702579  10.033599  4.985899         -8.0               -2
# 4    2019  2.993093   4.219421  3.229630         -5.5               10

# %%
START_YEAR = 2020 #First year we can test our meta-model on
BET_AMOUNT = 100
TAKE_RATE = 0.1

# Set your margin for level of confidence (higher value means the model needs to be more confident in order to place a bet)

for THRESHOLD in [7,8,9,10,11,12]:
    print('---------------------------------------')
    print('THRESHOLD:', THRESHOLD)


    # Loop through all models constructed and create a dataframe with the bet decision and the bet outcome
    for i, model in enumerate(meta_models):
        test_year = START_YEAR + i
        test_data = stacked_df[stacked_df['SEASON'] == test_year].reset_index(drop=True)

        # Prepare data for inference
        X = test_data.drop(columns=['SEASON', 'HOME SPREAD', 'HOME PLUS MINUS'])

        # Create your vector of predictions
        y_pred = model.predict(X)

        decisions = []
        outcomes = []
        bets_made = 0 
        bets_won = 0
        bets_lost = 0
        bets_push = 0
        games = len(test_data)
        profit = 0
        net_bets_made = 0

        for index, row in test_data.iterrows():

            bet = None
            home_favored_bet_home = False 
            home_favored_bet_away = False
            away_favored_bet_home = False
            away_favored_bet_away = False
            no_favorite_bet_home = False
            no_favorite_bet_away = False 
            
            # Bet when home is favored AND you think home team will outperform the spread by THRESHOLD
            home_favored_bet_home = row['HOME SPREAD'] < 0 and (y_pred[index] - THRESHOLD > abs(row['HOME SPREAD']))

            # Bet when home is favored BUT you think the away team will outperform the spread by THRESHOLD
            home_favored_bet_away = row['HOME SPREAD'] < 0 and ((y_pred[index] < 0 and (abs(row['HOME SPREAD'] + y_pred[index]) > THRESHOLD)) or (y_pred[index] >= 0 and y_pred[index] + THRESHOLD < abs(row['HOME SPREAD'])))

            # Bet when away is favored BUT you think the home team will outperform the spread (you think home team wins outright, by at least a particular relative margin OR you think the away team wins, but not by as much as the market thinks)
            away_favored_bet_home = row['HOME SPREAD'] > 0 and (((y_pred[index] > 0 and y_pred[index] + row['HOME SPREAD'] > THRESHOLD)) or ((y_pred[index] <= 0) and abs(y_pred[index]) + THRESHOLD < row['HOME SPREAD']))

            # Bet when away is favored AND you think away team will outperform the spread by THRESHOLD
            away_favored_bet_away = row['HOME SPREAD'] > 0 and y_pred[index] < 0 and (abs(y_pred[index]) - THRESHOLD > row['HOME SPREAD'])

            # Bet when there is no favorite, but you think HOME will win by more than THRESHOLD
            no_favorite_bet_home = row['HOME SPREAD'] == 0 and (y_pred[index] > THRESHOLD)

            # Bet when there is no favorite, but you think AWAY will win by more than THRESHOLD
            no_favorite_bet_away = row['HOME SPREAD'] == 0 and (abs(y_pred[index]) > THRESHOLD)


            # Bet home or away
            if home_favored_bet_home or away_favored_bet_home or no_favorite_bet_home:
                bet = 'Bet on Home'
            elif home_favored_bet_away or away_favored_bet_away or no_favorite_bet_away:
                bet = 'Bet on Away'
            else: 
                bet = 'No Bet'

            # Outcomes
            if bet == 'Bet on Home':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']:  # HOME COVERED THE SPREAD
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
                else:
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                    
            elif bet == 'Bet on Away':
                bets_made += 1
                if row['HOME PLUS MINUS'] == -row['HOME SPREAD']:   # HOME MATCHED SPREAD
                    outcome = 'Push'
                    bets_push += 1
                elif row['HOME PLUS MINUS'] > -row['HOME SPREAD']: # HOME COVERED THE SPREAD
                    outcome = 'Lost'
                    bets_lost += 1
                    net_bets_made += 1
                    profit -= BET_AMOUNT
                else: 
                    outcome = 'Won'
                    bets_won += 1
                    net_bets_made += 1
                    profit += (1-TAKE_RATE)*BET_AMOUNT
            else: 
                outcome = 'No Bet Placed'

            decisions.append(bet)
            outcomes.append(outcome)        
                        
            #print('Market home plus minus:', -row['HOME SPREAD'], '| Predicted home plus minus:', round(y_pred[index],1), '| Bet:', bet, ' | Actual home plus minus:', row['HOME PLUS MINUS'], '| Bet outcome:', outcome)

        if net_bets_made == 0:
            win_rate = 0
        else:
            win_rate = round(bets_won / net_bets_made, 2)

        print('Test Year {} Summary |'.format(test_year), 'Bets made:', bets_made, '| Bets won:', bets_won, '| Bets lost:', bets_lost, '| Bets pushed:', bets_push, '| Game count:', games, '| Bet win rate:', win_rate, '| Final bankroll:', profit)
# Out:
# ---------------------------------------
# THRESHOLD: 7
# Test Year 2020 Summary | Bets made: 53 | Bets won: 28 | Bets lost: 24 | Bets pushed: 1 | Game count: 1029 | Bet win rate: 0.54 | Final bankroll: 120.0
# Test Year 2021 Summary | Bets made: 103 | Bets won: 55 | Bets lost: 45 | Bets pushed: 3 | Game count: 1180 | Bet win rate: 0.55 | Final bankroll: 450.0
# Test Year 2022 Summary | Bets made: 119 | Bets won: 61 | Bets lost: 55 | Bets pushed: 3 | Game count: 1074 | Bet win rate: 0.53 | Final bankroll: -10.0
# ---------------------------------------
# THRESHOLD: 8
# Test Year 2020 Summary | Bets made: 28 | Bets won: 16 | Bets lost: 12 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.57 | Final bankroll: 240.0
# Test Year 2021 Summary | Bets made: 55 | Bets won: 30 | Bets lost: 25 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.55 | Final bankroll: 200.0
# Test Year 2022 Summary | Bets made: 76 | Bets won: 41 | Bets lost: 33 | Bets pushed: 2 | Game count: 1074 | Bet win rate: 0.55 | Final bankroll: 390.0
# ---------------------------------------
# THRESHOLD: 9
# Test Year 2020 Summary | Bets made: 17 | Bets won: 10 | Bets lost: 7 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.59 | Final bankroll: 200.0
# Test Year 2021 Summary | Bets made: 33 | Bets won: 15 | Bets lost: 18 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.45 | Final bankroll: -450.0
# Test Year 2022 Summary | Bets made: 52 | Bets won: 28 | Bets lost: 22 | Bets pushed: 2 | Game count: 1074 | Bet win rate: 0.56 | Final bankroll: 320.0
# ---------------------------------------
# THRESHOLD: 10
# Test Year 2020 Summary | Bets made: 9 | Bets won: 6 | Bets lost: 3 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.67 | Final bankroll: 240.0
# Test Year 2021 Summary | Bets made: 22 | Bets won: 10 | Bets lost: 12 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.45 | Final bankroll: -300.0
# Test Year 2022 Summary | Bets made: 35 | Bets won: 23 | Bets lost: 12 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.66 | Final bankroll: 870.0
# ---------------------------------------
# THRESHOLD: 11
# Test Year 2020 Summary | Bets made: 7 | Bets won: 5 | Bets lost: 2 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.71 | Final bankroll: 250.0
# Test Year 2021 Summary | Bets made: 14 | Bets won: 9 | Bets lost: 5 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.64 | Final bankroll: 310.0
# Test Year 2022 Summary | Bets made: 23 | Bets won: 16 | Bets lost: 7 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.7 | Final bankroll: 740.0
# ---------------------------------------
# THRESHOLD: 12
# Test Year 2020 Summary | Bets made: 6 | Bets won: 5 | Bets lost: 1 | Bets pushed: 0 | Game count: 1029 | Bet win rate: 0.83 | Final bankroll: 350.0
# Test Year 2021 Summary | Bets made: 8 | Bets won: 5 | Bets lost: 3 | Bets pushed: 0 | Game count: 1180 | Bet win rate: 0.62 | Final bankroll: 150.0
# Test Year 2022 Summary | Bets made: 12 | Bets won: 9 | Bets lost: 3 | Bets pushed: 0 | Game count: 1074 | Bet win rate: 0.75 | Final bankroll: 510.0

# %%
# Build the 2022 META model we will use to make predictions for the 2023 season! (still need to load vectors for inference from 2023 season when it starts, 
# #in order to generate the rf/nn/xgb predictions)

seasons = sorted(stacked_df['SEASON'].unique())
coefficients_list = []
mse_list = []
predictions_list = []
meta_models = []

# Train on one season and test on the next (to see if our stacked model can outperform the base models)
train = stacked_df[stacked_df['SEASON'] <= seasons[-1]]

X_train = train[['rf', 'nn', 'xgb']]
y_train = train['HOME PLUS MINUS']

meta_model = LinearRegression()
meta_model.fit(X_train, y_train)
    
# Store coefficients
coefficients = meta_model.coef_
coefficients_list.append(coefficients)

# Store the trained models. The SEASON value is the year of data to test the model on (not the year of data the model was trained on).
meta_models.append((seasons[-1]+1, meta_model))

# DataFrames for coefficients and MSE
coeff_df = pd.DataFrame(coefficients_list, columns=['random_forest_coef', 'neural_network_coef', 'xgboost_coef'])
coeff_df['SEASON'] = seasons[-1]

print('-- Optimal Model Coefficients ---')
display(coeff_df)
print('-- Updated Loss Calculations on Subsequent Season ---')
print('TBD!')
# Out:
# -- Optimal Model Coefficients ---
#    random_forest_coef  neural_network_coef  xgboost_coef  SEASON
# 0            0.597334             0.530263      0.024527    2022
# -- Updated Loss Calculations on Subsequent Season ---
# TBD!
